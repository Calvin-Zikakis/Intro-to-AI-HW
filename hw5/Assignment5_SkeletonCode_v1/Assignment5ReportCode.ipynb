# %%
import numpy as np
import matplotlib.pyplot as plt

loss = np.array([5.56, 2.825, 2.495, 1.834, 1.962, 1.548, 1.529, 1.521, 1.352, 1.359, 1.315, 1.239, 1.192, 1.188, 1.144, 1.068, 1.061, 0.995, 0.992, 0.958])
validation_loss = np.array([3.9103, 2.5564, 2.2535, 1.7923, 1.5301, 1.7049, 1.6236, 1.4157, 1.4574, 1.3448, 1.3681, 1.3591, 1.2873, 1.2167, 1.2233, 1.2839, 1.1490, 1.1059, 1.1380, 1.1074])

epoch = np.arange(1, 21)


plt.plot(epoch, loss, label="Training Loss")
plt.plot(epoch, validation_loss, label = "Validation loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss per Epoch")
plt.legend()
